# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential 
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
def createDataFrame(dir):
    image_path = []
    labels = []

    for label in os.listdir(dir):
        label_path = os.path.join(dir, label)
        if os.path.isdir(label_path):  
            for imagename in os.listdir(label_path):  
                image_path.append(os.path.join(label_path, imagename))
                labels.append(label)
    return image_path, labels

# %%
train_data_dir = 'D:/python/images/train'  
train = pd.DataFrame()
train['image'], train['label'] = createDataFrame(train_data_dir)
print(train)
# Out:
#                                           image     label
# 0            D:/python/images/train\angry\0.jpg     angry
# 1            D:/python/images/train\angry\1.jpg     angry
# 2           D:/python/images/train\angry\10.jpg     angry
# 3        D:/python/images/train\angry\10002.jpg     angry
# 4        D:/python/images/train\angry\10016.jpg     angry
# ...                                         ...       ...
# 28816  D:/python/images/train\surprise\9969.jpg  surprise
# 28817  D:/python/images/train\surprise\9985.jpg  surprise
# 28818  D:/python/images/train\surprise\9990.jpg  surprise
# 28819  D:/python/images/train\surprise\9992.jpg  surprise
# 28820  D:/python/images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test_data_dir = 'D:/python/images/test'  
test = pd.DataFrame()
test['image'], test['label'] = createDataFrame(test_data_dir)
print(train)
# Out:
#                                           image     label
# 0            D:/python/images/train\angry\0.jpg     angry
# 1            D:/python/images/train\angry\1.jpg     angry
# 2           D:/python/images/train\angry\10.jpg     angry
# 3        D:/python/images/train\angry\10002.jpg     angry
# 4        D:/python/images/train\angry\10016.jpg     angry
# ...                                         ...       ...
# 28816  D:/python/images/train\surprise\9969.jpg  surprise
# 28817  D:/python/images/train\surprise\9985.jpg  surprise
# 28818  D:/python/images/train\surprise\9990.jpg  surprise
# 28819  D:/python/images/train\surprise\9992.jpg  surprise
# 28820  D:/python/images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
from tqdm import tqdm

# %%
def extract_features(images):
    features=[]
    for image in tqdm(images):
        img = load_img(image, color_mode="grayscale")
        img=np.array(img)
        features.append(img)
    features=np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
# 00%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 28821/28821 [00:10<00:00, 2724.67it/s]

# %%
test_features = extract_features(test['image'])
# Out:
# 00%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 7066/7066 [00:02<00:00, 2558.80it/s]

# %%
x_train=train_features/255.0
x_test=test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train=le.transform(train['label'])
y_test=le.transform(test['label'])

# %%
input_shape = (48, 48, 1)  # Example: 48x48 grayscale images

model = Sequential()

# Convolutional layers
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

# Fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

# Output layer
model.add(Dense(7, activation='softmax'))
# Out:
# D:\python\myenv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# model.fit(x=x_train,y=y_train,batch_size=128,epochs=100,validation_data=(x_test,y_test))

# %%
# Ensure y_train and y_test are one-hot encoded
from keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# Train the model
model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.2384 - loss: 1.8356 - val_accuracy: 0.2583 - val_loss: 1.8042
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - accuracy: 0.2502 - loss: 1.7999 - val_accuracy: 0.3077 - val_loss: 1.6903
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.3156 - loss: 1.6831 - val_accuracy: 0.4172 - val_loss: 1.4949
# Epoch 4/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.3921 - loss: 1.5477 - val_accuracy: 0.4718 - val_loss: 1.3844
# Epoch 5/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.4344 - loss: 1.4636 - val_accuracy: 0.4846 - val_loss: 1.3498
# Epoch 6/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.4584 - loss: 1.4048 - val_accuracy: 0.5054 - val_loss: 1.2884
# Epoch 7/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.4672 - loss: 1.3809 - val_accuracy: 0.5303 - val_loss: 1.2470
# Epoch 8/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.4901 - loss: 1.3263 - val_accuracy: 0.5413 - val_loss: 1.2130
# Epoch 9/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.5057 - loss: 1.2961 - val_accuracy: 0.5470 - val_loss: 1.2171
# Epoch 10/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.5088 - loss: 1.2780 - val_accuracy: 0.5521 - val_loss: 1.1791
# Epoch 11/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - accuracy: 0.5222 - loss: 1.2529 - val_accuracy: 0.5562 - val_loss: 1.1791
# Epoch 12/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.5274 - loss: 1.2438 - val_accuracy: 0.5631 - val_loss: 1.1446
# Epoch 13/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.5327 - loss: 1.2241 - val_accuracy: 0.5657 - val_loss: 1.1465
# Epoch 14/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.5330 - loss: 1.2210 - val_accuracy: 0.5674 - val_loss: 1.1371
# Epoch 15/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.5391 - loss: 1.2039 - val_accuracy: 0.5768 - val_loss: 1.1158
# Epoch 16/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.5541 - loss: 1.1796 - val_accuracy: 0.5771 - val_loss: 1.1247
# Epoch 17/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.5581 - loss: 1.1751 - val_accuracy: 0.5750 - val_loss: 1.1234
# Epoch 18/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.5601 - loss: 1.1663 - val_accuracy: 0.5918 - val_loss: 1.0925
# Epoch 19/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.5661 - loss: 1.1448 - val_accuracy: 0.5882 - val_loss: 1.0980
# Epoch 20/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.5635 - loss: 1.1476 - val_accuracy: 0.5897 - val_loss: 1.0929
# Epoch 21/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.5717 - loss: 1.1321 - val_accuracy: 0.5870 - val_loss: 1.0952
# Epoch 22/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.5737 - loss: 1.1199 - val_accuracy: 0.5918 - val_loss: 1.0908
# Epoch 23/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.5791 - loss: 1.1090 - val_accuracy: 0.5982 - val_loss: 1.0697
# Epoch 24/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.5862 - loss: 1.0942 - val_accuracy: 0.5889 - val_loss: 1.0957
# Epoch 25/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.5812 - loss: 1.1014 - val_accuracy: 0.6023 - val_loss: 1.0660
# Epoch 26/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 289s 1s/step - accuracy: 0.5888 - loss: 1.0836 - val_accuracy: 0.6030 - val_loss: 1.0606
# Epoch 27/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.5889 - loss: 1.0896 - val_accuracy: 0.6015 - val_loss: 1.0611
# Epoch 28/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.6020 - loss: 1.0643 - val_accuracy: 0.6070 - val_loss: 1.0548
# Epoch 29/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.6023 - loss: 1.0573 - val_accuracy: 0.6049 - val_loss: 1.0590
# Epoch 30/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - accuracy: 0.5993 - loss: 1.0597 - val_accuracy: 0.6091 - val_loss: 1.0531
# Epoch 31/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.6047 - loss: 1.0448 - val_accuracy: 0.6064 - val_loss: 1.0558
# Epoch 32/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.6078 - loss: 1.0394 - val_accuracy: 0.6098 - val_loss: 1.0516
# Epoch 33/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6106 - loss: 1.0390 - val_accuracy: 0.6083 - val_loss: 1.0577
# Epoch 34/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6102 - loss: 1.0287 - val_accuracy: 0.6054 - val_loss: 1.0557
# Epoch 35/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6149 - loss: 1.0162 - val_accuracy: 0.6071 - val_loss: 1.0525
# Epoch 36/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6253 - loss: 1.0040 - val_accuracy: 0.6054 - val_loss: 1.0562
# Epoch 37/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6270 - loss: 0.9931 - val_accuracy: 0.6111 - val_loss: 1.0483
# Epoch 38/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6207 - loss: 0.9990 - val_accuracy: 0.6073 - val_loss: 1.0529
# Epoch 39/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.6166 - loss: 1.0057 - val_accuracy: 0.6078 - val_loss: 1.0549
# Epoch 40/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6353 - loss: 0.9782 - val_accuracy: 0.6110 - val_loss: 1.0389
# Epoch 41/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.6269 - loss: 0.9889 - val_accuracy: 0.6132 - val_loss: 1.0443
# Epoch 42/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6382 - loss: 0.9677 - val_accuracy: 0.6136 - val_loss: 1.0453
# Epoch 43/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6325 - loss: 0.9763 - val_accuracy: 0.6112 - val_loss: 1.0383
# Epoch 44/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6307 - loss: 0.9803 - val_accuracy: 0.6168 - val_loss: 1.0362
# Epoch 45/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.6414 - loss: 0.9549 - val_accuracy: 0.6124 - val_loss: 1.0402
# Epoch 46/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.6436 - loss: 0.9500 - val_accuracy: 0.6194 - val_loss: 1.0239
# Epoch 47/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 310s 1s/step - accuracy: 0.6527 - loss: 0.9305 - val_accuracy: 0.6220 - val_loss: 1.0354
# Epoch 48/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 299s 1s/step - accuracy: 0.6417 - loss: 0.9507 - val_accuracy: 0.6159 - val_loss: 1.0362
# Epoch 49/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.6571 - loss: 0.9307 - val_accuracy: 0.6221 - val_loss: 1.0349
# Epoch 50/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.6544 - loss: 0.9345 - val_accuracy: 0.6227 - val_loss: 1.0291
# Epoch 51/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6548 - loss: 0.9307 - val_accuracy: 0.6175 - val_loss: 1.0404
# Epoch 52/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6534 - loss: 0.9192 - val_accuracy: 0.6183 - val_loss: 1.0267
# Epoch 53/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.6605 - loss: 0.9245 - val_accuracy: 0.6217 - val_loss: 1.0323
# Epoch 54/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.6593 - loss: 0.9089 - val_accuracy: 0.6166 - val_loss: 1.0337
# Epoch 55/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6565 - loss: 0.9119 - val_accuracy: 0.6182 - val_loss: 1.0234
# Epoch 56/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.6640 - loss: 0.8922 - val_accuracy: 0.6227 - val_loss: 1.0238
# Epoch 57/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 302s 1s/step - accuracy: 0.6645 - loss: 0.9054 - val_accuracy: 0.6248 - val_loss: 1.0232
# Epoch 58/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.6637 - loss: 0.9054 - val_accuracy: 0.6202 - val_loss: 1.0397
# Epoch 59/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 308s 1s/step - accuracy: 0.6691 - loss: 0.8984 - val_accuracy: 0.6241 - val_loss: 1.0279
# Epoch 60/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - accuracy: 0.6769 - loss: 0.8736 - val_accuracy: 0.6240 - val_loss: 1.0246
# Epoch 61/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.6766 - loss: 0.8712 - val_accuracy: 0.6269 - val_loss: 1.0247
# Epoch 62/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.6738 - loss: 0.8814 - val_accuracy: 0.6247 - val_loss: 1.0220
# Epoch 63/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 302s 1s/step - accuracy: 0.6780 - loss: 0.8633 - val_accuracy: 0.6264 - val_loss: 1.0277
# Epoch 64/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.6763 - loss: 0.8689 - val_accuracy: 0.6264 - val_loss: 1.0264
# Epoch 65/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6873 - loss: 0.8533 - val_accuracy: 0.6279 - val_loss: 1.0239
# Epoch 66/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.6813 - loss: 0.8662 - val_accuracy: 0.6305 - val_loss: 1.0301
# Epoch 67/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6846 - loss: 0.8521 - val_accuracy: 0.6281 - val_loss: 1.0155
# Epoch 68/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.6852 - loss: 0.8318 - val_accuracy: 0.6221 - val_loss: 1.0277
# Epoch 69/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6894 - loss: 0.8448 - val_accuracy: 0.6267 - val_loss: 1.0192
# Epoch 70/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.6957 - loss: 0.8323 - val_accuracy: 0.6292 - val_loss: 1.0184
# Epoch 71/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - accuracy: 0.6918 - loss: 0.8411 - val_accuracy: 0.6306 - val_loss: 1.0243
# Epoch 72/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.6871 - loss: 0.8390 - val_accuracy: 0.6303 - val_loss: 1.0204
# Epoch 73/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.6926 - loss: 0.8253 - val_accuracy: 0.6281 - val_loss: 1.0285
# Epoch 74/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.6960 - loss: 0.8222 - val_accuracy: 0.6322 - val_loss: 1.0245
# Epoch 75/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.6953 - loss: 0.8212 - val_accuracy: 0.6299 - val_loss: 1.0277
# Epoch 76/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.6899 - loss: 0.8314 - val_accuracy: 0.6288 - val_loss: 1.0230
# Epoch 77/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 301s 1s/step - accuracy: 0.7000 - loss: 0.8154 - val_accuracy: 0.6289 - val_loss: 1.0286
# Epoch 78/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 299s 1s/step - accuracy: 0.7045 - loss: 0.7986 - val_accuracy: 0.6238 - val_loss: 1.0362
# Epoch 79/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.7122 - loss: 0.7884 - val_accuracy: 0.6275 - val_loss: 1.0267
# Epoch 80/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.7092 - loss: 0.7931 - val_accuracy: 0.6292 - val_loss: 1.0253
# Epoch 81/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.7095 - loss: 0.7928 - val_accuracy: 0.6277 - val_loss: 1.0329
# Epoch 82/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.7111 - loss: 0.7953 - val_accuracy: 0.6124 - val_loss: 1.0600
# Epoch 83/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 299s 1s/step - accuracy: 0.7089 - loss: 0.7983 - val_accuracy: 0.6245 - val_loss: 1.0399
# Epoch 84/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.7073 - loss: 0.8026 - val_accuracy: 0.6340 - val_loss: 1.0277
# Epoch 85/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.7177 - loss: 0.7704 - val_accuracy: 0.6291 - val_loss: 1.0409
# Epoch 86/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.7184 - loss: 0.7713 - val_accuracy: 0.6296 - val_loss: 1.0640
# Epoch 87/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.7126 - loss: 0.7681 - val_accuracy: 0.6288 - val_loss: 1.0251
# Epoch 88/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.7122 - loss: 0.7696 - val_accuracy: 0.6296 - val_loss: 1.0339
# Epoch 89/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.7134 - loss: 0.7731 - val_accuracy: 0.6329 - val_loss: 1.0429
# Epoch 90/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.7195 - loss: 0.7705 - val_accuracy: 0.6319 - val_loss: 1.0220
# Epoch 91/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.7187 - loss: 0.7659 - val_accuracy: 0.6354 - val_loss: 1.0212
# Epoch 92/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.7225 - loss: 0.7630 - val_accuracy: 0.6311 - val_loss: 1.0400
# Epoch 93/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.7283 - loss: 0.7463 - val_accuracy: 0.6284 - val_loss: 1.0437
# Epoch 94/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.7293 - loss: 0.7464 - val_accuracy: 0.6366 - val_loss: 1.0373
# Epoch 95/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.7289 - loss: 0.7434 - val_accuracy: 0.6323 - val_loss: 1.0339
# Epoch 96/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.7308 - loss: 0.7272 - val_accuracy: 0.6340 - val_loss: 1.0444
# Epoch 97/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.7305 - loss: 0.7416 - val_accuracy: 0.6374 - val_loss: 1.0400
# Epoch 98/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - accuracy: 0.7268 - loss: 0.7368 - val_accuracy: 0.6397 - val_loss: 1.0345
# Epoch 99/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.7352 - loss: 0.7266 - val_accuracy: 0.6289 - val_loss: 1.0419
# Epoch 100/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.7373 - loss: 0.7205 - val_accuracy: 0.6318 - val_loss: 1.0558

# %%
model.save('trained_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
